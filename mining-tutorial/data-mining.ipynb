# %% [markdown]
# # Data mining, regression analysis, and data visualization tutorial followed from [Springboard](https://www.springboard.com/blog/data-mining-python-tutorial/)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats
import seaborn as sns
from matplotlib import rcParams

# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv('./kc_house_data.csv')
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# looking to see if we have any null data
df.isnull().any()
# Out:
# id               False
# date             False
# price            False
# bedrooms         False
# bathrooms        False
# sqft_living      False
# sqft_lot         False
# floors           False
# waterfront       False
# view             False
# condition        False
# grade            False
# sqft_above       False
# sqft_basement    False
# yr_built         False
# yr_renovated     False
# zipcode          False
# lat              False
# long             False
# sqft_living15    False
# sqft_lot15       False
# dtype: bool

# %%
# checking out the data types of these variables
# to get a sense for what is numerical or not/float etc.
df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
# get a feel for the data and contents
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ### We are working with a dataset that contains 21,613 observations (count id), mean price is approximately 540k, median price is approximately 450k, and average house's area is 2080 ft2.

# %%
fig = plt.figure(figsize=(12,6))
sqft = fig.add_subplot(121)
cost = fig.add_subplot(122)

sqft.hist(df.sqft_living, bins=80)
sqft.set_xlabel('Ft^2')
sqft.set_title("Histogram of House Square Footage")

cost.hist(df.price, bins=80)
cost.set_xlabel('Price ($)')
cost.set_title("Histogram of Housing Prices")

plt.show()

# %% [markdown]
# ### Using matplotlib (plt) we printed two histograms to observe the distribution of housing prices and square footage. Left histogram plots number of houses on y, with ft^2 on x. Right histogram plots number of houses on y, with price on x.

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols
# doing regression analysis, we need statsmodels
# to get the least squares regression estimator functions;
# the 'ordinary least squares' module

# linear regression with OLS and only 2 vars
# Reg = ols('Dependent variable ~ independent variable(s)'', dataframe).fit())
# print(Reg.summary())
m = ols('price ~ sqft_living', df).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                 2.100e+04
# Date:                Mon, 02 Jul 2018   Prob (F-statistic):               0.00
# Time:                        21:06:38   Log-Likelihood:            -3.0027e+05
# No. Observations:               21613   AIC:                         6.005e+05
# Df Residuals:                   21611   BIC:                         6.006e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -4.358e+04   4402.690     -9.899      0.000   -5.22e+04    -3.5e+04
# ...

# %% [markdown]
# ### The extremely high t-value of 144.920 and P>|t| of 0% means this relationship has a near zero chance of being due to statistical variation or chance. Every additional 100 square feet above the average, the house price would rise $28,000.

# %%
m = ols('price ~ sqft_living + bedrooms + grade + condition', df).fit()
print(m.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.555
# Model:                            OLS   Adj. R-squared:                  0.555
# Method:                 Least Squares   F-statistic:                     6749.
# Date:                Mon, 02 Jul 2018   Prob (F-statistic):               0.00
# Time:                        21:22:56   Log-Likelihood:            -2.9884e+05
# No. Observations:               21613   AIC:                         5.977e+05
# Df Residuals:                   21608   BIC:                         5.977e+05
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -7.398e+05   1.81e+04    -40.855      0.000   -7.75e+05   -7.04e+05
# ...

# %% [markdown]
# ### The multivariate regression output implies that by using additional independent variables, such as the number of bedrooms, we can provide a model that fits the data better, as the R-squared regression has increased to 0.555. This means that we went from being able to explain about 49.3% of the variation in the model to 55.5% with the addition of a few more independent variables.

# %%
sns.jointplot(x="sqft_living", y="price", data=df, kind="reg", fit_reg=True, size=7)
plt.show()
# Out:
# /Users/chaselirette/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Users/chaselirette/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %% [markdown]
# ### Visualization using Seaborn (sns). This section will rely entirely on Seaborn (sns), which has an incredibly simple and intuitive function for graphing regression lines with scatterplots. I chose to create a jointplot for square footage and price that shows the regression line as well as distribution plots for each variable.
